# %% [markdown]
# <a href="https://colab.research.google.com/github/PolyGon-13/DataScience_Study/blob/main/Preprocessing/02_Duplicate_Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'c1':['a','a','b','a','b'],
                 'c2':[1,1,1,2,2],
                 'c3':[1,1,2,2,2]})
df
# Out:
#   c1  c2  c3
# 0  a   1   1
# 1  a   1   1
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2

# %%
df_dup_first=df.duplicated() # keep='first'
df_dup_first
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_dup_last=df.duplicated(keep='last')
df_dup_last
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_dup_false=df.duplicated(keep=False)
df_dup_false
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
col_dup=df['c2'].duplicated()
col_dup
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: c2, dtype: bool

# %%
col_dup2=df.duplicated(subset=['c2'])
col_dup2
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df=pd.DataFrame({'c1':['a','a','b','a','b'],
                 'c2':[1,1,1,2,2],
                 'c3':[1,1,2,2,2]})

df2=df.drop_duplicates()
df2
# Out:
#   c1  c2  c3
# 0  a   1   1
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2

# %%
df3=df.drop_duplicates(keep='last')
df3
# Out:
#   c1  c2  c3
# 1  a   1   1
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2

# %%
df4=df.drop_duplicates(keep=False)
df4
# Out:
#   c1  c2  c3
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2

# %%
df5=df.drop_duplicates(subset=['c2','c3'])
df5
# Out:
#   c1  c2  c3
# 0  a   1   1
# 2  b   1   2
# 3  a   2   2

# %%
df6=df.drop_duplicates(subset=['c2','c3'],keep=False)
df6
# Out:
#   c1  c2  c3
# 2  b   1   2
