# %% [markdown]
# <a href="https://colab.research.google.com/github/PolyGon-13/DataScience_Study/blob/main/DataFile/03_json_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_json('./data/read_json_sample.json')
df
# Out:
#             year        developer opensource
# pandas      2008    Wes Mckinneye       True
# NumPy       2006  Travis Oliphant       True
# matplotlib  2003   John D. Hunter       True

# %%
df.index
# Out:
# Index(['pandas', 'NumPy', 'matplotlib'], dtype='object')

# %%
df2=pd.read_json('./data/read_json_sample.json',orient='index')
df2
# Out:
#                    pandas            NumPy      matplotlib
# year                 2008             2006            2003
# developer   Wes Mckinneye  Travis Oliphant  John D. Hunter
# opensource           True             True            True

# %%
df3=pd.read_json('./data/read_json_sample.json',orient='columns')
df3
# Out:
#             year        developer opensource
# pandas      2008    Wes Mckinneye       True
# NumPy       2006  Travis Oliphant       True
# matplotlib  2003   John D. Hunter       True
