# %% [markdown]
# <a href="https://colab.research.google.com/github/PolyGon-13/DataScience_Study/blob/main/pandas/06_Boolean_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')
df=titanic.loc[0:9,['age','fare']] # loc는 범위의 끝 포함, iloc은 범위의 끝 미포함
df
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 7   2.0  21.0750
# 8  27.0  11.1333
# 9  14.0  30.0708

# %%
df['age']<20
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# Name: age, dtype: bool

# %%
df[df['age']<20]
# Out:
#     age     fare
# 7   2.0  21.0750
# 9  14.0  30.0708

# %%
df.loc[df['age']<20]
# Out:
#     age     fare
# 7   2.0  21.0750
# 9  14.0  30.0708

# %%
df.loc[~(df['age']<20)]
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
# 5   NaN   8.4583
# 6  54.0  51.8625
# 8  27.0  11.1333

# %%
mask1=(titanic.age>10)&(titanic.age<20)
df_teenage=titanic[mask1]
df_teenage.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 38         0       3  female  18.0      2      0   18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 9   child       False  NaN    Cherbourg   yes  False
# 14  child       False  NaN  Southampton    no   True
# 22  child       False  NaN   Queenstown   yes   True
# 27    man        True    C  Southampton    no  False
# 38  woman       False  NaN  Southampton    no  False

# %%
mask2=(titanic.age<10)&(titanic.sex=='female')
df_female_under10=titanic.loc[mask2]
df_female_under10.head()
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 10          1       3  female  4.0      1      1  16.7000        S   Third
# 24          0       3  female  8.0      3      1  21.0750        S   Third
# 43          1       2  female  3.0      1      2  41.5792        C  Second
# 58          1       2  female  5.0      1      2  27.7500        S  Second
# 119         0       3  female  2.0      4      2  31.2750        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 10   child       False    G  Southampton   yes  False
# 24   child       False  NaN  Southampton    no  False
# 43   child       False  NaN    Cherbourg   yes  False
# 58   child       False  NaN  Southampton   yes  False
# 119  child       False  NaN  Southampton    no  False

# %%
mask3=(titanic.age<10)|(titanic.age<=60)
df_under10_morethan60=titanic.loc[mask3,['age','sex','alone']]
df_under10_morethan60.head()
# Out:
#     age     sex  alone
# 0  22.0    male  False
# 1  38.0  female  False
# 2  26.0  female   True
# 3  35.0  female  False
# 4  35.0    male   True

# %%
df['age_under_20']=df['age']<20
df.head()
# Out:
#     age     fare  age_under_20
# 0  22.0   7.2500         False
# 1  38.0  71.2833         False
# 2  26.0   7.9250         False
# 3  35.0  53.1000         False
# 4  35.0   8.0500         False
