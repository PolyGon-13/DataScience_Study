# %% [markdown]
# <a href="https://colab.research.google.com/github/PolyGon-13/DataScience_Study/blob/main/DataFrame/01_Function_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')
df=titanic.loc[:,['age','fare']]

df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
def add_10(n):
    return n+10

def add_two_obj(a,b):
    return a+b

print(add_10(10))
print(add_two_obj(10,10))
# Out:
# 20
# 20

# %%
sr1=df['age'].apply(add_10)
sr1.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr2=df['age'].apply(lambda n:n+10)
sr2.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr3=df['age'].apply(add_two_obj,b=10)
sr3.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
sr4=df['age'].apply(lambda a,b:a+b,b=10)
sr4.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
def over_thirty(age):
    return age>30

sr_map=df['age'].map(over_thirty)
sr_map.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: age, dtype: bool

# %%
sr_map2=df['age'].map(lambda age:True if age>30 else False)
sr_map2.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: age, dtype: bool

# %%
print(titanic['sex'].unique())
print('\n')
print(titanic['sex'].head())
print('\n')

over_forty_dict={'male':0,'female':1}
titanic['gender']=titanic['sex'].map(over_forty_dict)
print(titanic['gender'].head())
# Out:
# ['male' 'female']
#
#
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object
#
#
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: gender, dtype: int64

# %%
titanic=sns.load_dataset('titanic')
df=titanic.loc[:,['age','fare']]

def add_10(n):
    return n+10

def add_two_obj(a,b):
    return a+b

df1=df.map(add_10)
df1.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
df2=df.map(lambda n:n+10)
df2.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
df3=df.map(add_two_obj,b=10)
df3.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
df4=df.map(lambda a,b:a+b,b=10)
df4.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
titanic=sns.load_dataset('titanic')
df=titanic.loc[:,['age','fare']]

df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
def calculate_stats(col):
    max_val=col.max()
    min_val=col.min()
    mean_val=col.mean()
    median_val=col.median()

    return pd.Series([max_val,min_val,mean_val,median_val],index=['Max','Min','Mean','Median'])

result_df=df.apply(calculate_stats,axis=0)

result_df
# Out:
#               age        fare
# Max     80.000000  512.329200
# Min      0.420000    0.000000
# Mean    29.699118   32.204208
# Median  28.000000   14.454200

# %%
result_sr=df.apply(lambda x:x.max()-x.min(),axis=0)
result_sr
# Out:
# age      79.5800
# fare    512.3292
# dtype: float64

# %%
def calculate_diff_avg(row):
    diff=row.max()-row.min()
    avg=row.mean()

    return pd.Series([diff,avg],index=['차이','평균'])

result_df2=df.apply(calculate_diff_avg,axis=1)

result_df2
# Out:
#           차이        평균
# 0    14.7500  14.62500
# 1    33.2833  54.64165
# 2    18.0750  16.96250
# 3    18.1000  44.05000
# 4    26.9500  21.52500
# ..       ...       ...
# 886  14.0000  20.00000
# 887  11.0000  24.50000
# 888   0.0000  23.45000
# 889   4.0000  28.00000
# 890  24.2500  19.87500
#
# [891 rows x 2 columns]

# %%
multiplier=2
result_df3=df.apply(lambda row:pd.Series([(row.max()-row.min())*multiplier,row.mean()],
                                         index=['차이','평균']),axis=1)
result_df3
# Out:
#           차이        평균
# 0    29.5000  14.62500
# 1    66.5666  54.64165
# 2    36.1500  16.96250
# 3    36.2000  44.05000
# 4    53.9000  21.52500
# ..       ...       ...
# 886  28.0000  20.00000
# 887  22.0000  24.50000
# 888   0.0000  23.45000
# 889   8.0000  28.00000
# 890  48.5000  19.87500
#
# [891 rows x 2 columns]

# %%
filtered_columns=df.apply(lambda x:x.mean()>30)
print(filtered_columns,"\n")

filtered_df=df.loc[:,filtered_columns]

filtered_df
# Out:
# age     False
# fare     True
# dtype: bool
#         fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
df['High']=df.apply(lambda row:'Yes' if row.mean()>50 else 'No',axis=1)
df
# Out:
#       age     fare High
# 0    22.0   7.2500   No
# 1    38.0  71.2833  Yes
# 2    26.0   7.9250   No
# 3    35.0  53.1000   No
# 4    35.0   8.0500   No
# ..    ...      ...  ...
# 886  27.0  13.0000   No
# 887  19.0  30.0000   No
# 888   NaN  23.4500   No
# 889  26.0  30.0000   No
# 890  32.0   7.7500   No
#
# [891 rows x 3 columns]
