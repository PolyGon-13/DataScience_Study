# %% [markdown]
# <a href="https://colab.research.google.com/github/PolyGon-13/DataScience_Study/blob/main/DataFrame/07_Stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')

df=titanic.loc[:,['age','sex','class','fare','survived']]

df2=pd.pivot_table(df,
                   index=['class','survived'],
                   columns='sex',
                   values='age',
                   aggfunc='mean',
                   observed=True)
df2
# Out:
# sex                 female       male
# class  survived
# First  0         25.666667  44.581967
#        1         34.939024  36.248000
# Second 0         36.000000  33.369048
#        1         28.080882  16.022000
# Third  0         23.818182  27.255814
#        1         19.329787  22.274211

# %%
df_stacked=df2.stack()
df_stacked
# Out:
# class   survived  sex
# First   0         female    25.666667
#                   male      44.581967
#         1         female    34.939024
#                   male      36.248000
# Second  0         female    36.000000
#                   male      33.369048
#         1         female    28.080882
#                   male      16.022000
# Third   0         female    23.818182
#                   male      27.255814
#         1         female    19.329787
#                   male      22.274211
# dtype: float64

# %%
df_unstacked=df2.unstack()
df_unstacked
# Out:
# sex          female                  male
# survived          0          1          0          1
# class
# First     25.666667  34.939024  44.581967  36.248000
# Second    36.000000  28.080882  33.369048  16.022000
# Third     23.818182  19.329787  27.255814  22.274211

# %%
df_unstacked2=df2.unstack(level=0)
df_unstacked2
# Out:
# sex          female                             male
# class         First     Second      Third      First     Second      Third
# survived
# 0         25.666667  36.000000  23.818182  44.581967  33.369048  27.255814
# 1         34.939024  28.080882  19.329787  36.248000  16.022000  22.274211

# %%
df_stacked2=df_unstacked2.stack(level=1,future_stack=True)
df_stacked2
# Out:
# sex                 female       male
# survived class
# 0        First   25.666667  44.581967
#          Second  36.000000  33.369048
#          Third   23.818182  27.255814
# 1        First   34.939024  36.248000
#          Second  28.080882  16.022000
#          Third   19.329787  22.274211
